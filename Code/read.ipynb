# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/lingshuai/Projects/AgentProjects/CSUR_ExpTransfer/References/Agent_trajectory_distillation_into_token_artifacts.csv")

# %%
df.columns.values
# Out:
# array(['Cite Key', 'Title', 'Authors', 'Year', 'Publication Date',
#        'Journal', 'Volume', 'Pages', 'Abstract', 'Citation Count',
#        'Citations/Year', 'DOI', 'URL', 'Relevance Score'], dtype=object)
